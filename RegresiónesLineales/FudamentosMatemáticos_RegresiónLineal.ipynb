# %% [markdown]
# # Regresión Lineal
#
# Modelar una relación entre la variable y y otras variables.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Calcula una recta que se ajuste mejor a los datos.

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Se compara el valor real versus el valor de predicción.
# La idea es identificar cuál es el B1 y el B0 que sirve.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
#
# En el caso de la derecha se podría aplicar un modelo de regresión lineal, pero el resultado no será tan preciso.

# %% [markdown]
# Una buena práctica es hacer una observación estadística para hacerse una idea del mejor modelo a implementar.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
