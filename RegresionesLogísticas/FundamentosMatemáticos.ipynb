# %% [markdown]
# # Fundamentos matemáticos Regresión Logística
#
#
# Modela la probabilidad de que y = 1
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Se quiere minimizar la Verosimilitud negativa
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# A esto se le llama un modelo paramétrico, porque se trata de estimar datos. Un modelo donde no estimamos parámetros, es el Knn.
#
# ![image.png](attachment:image.png)
