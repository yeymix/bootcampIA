# %% [markdown]
# # Algoritmo KNN
#
#
# Se usa para regresiones y clasificaciones.
#
#
# La métrica de Coseno tiende a usarse para análisis de sentimientos, indica de alguna manera la dirección que tiene el vector.

# %% [markdown]
# En la siguiente imagen la p es una constante. De acuerdo a la p se usa una métrica de medición u otra.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
