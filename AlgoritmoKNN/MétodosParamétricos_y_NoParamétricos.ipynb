# %% [markdown]
# # Métodos paramétricos vs No paramétricos

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Tienen eficiencia computacional muy buena.

# %% [markdown]
# Desventajas:
#
# Los datos deben cumplir con ciertas propiedades

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
